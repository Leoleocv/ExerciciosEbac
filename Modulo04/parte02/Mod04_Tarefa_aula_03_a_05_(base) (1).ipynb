# %% [markdown]
# ## Exercício 1: Vestibular
#
# Considere que a os dados gerados na célula abaixo contêm o número de acertos de 100 alunos em um vestibular para um curso de exatas, divididas pelos respectivos assuntos. Considere que cada assunto possui um número de questões conforme a tabela abaixo:
#
# | assunto | número de questões |
# |:---:|:---:|
# | Matemática | 24 |
# | Português | 18 |
# | Geografia | 8 |
# | Inglês | 8 |
# | História | 8 |
# | Física | 12 |
# | Química | 12 |
#
# Usando os comandos de operações com DataFrames que você aprendeu na Aula 03, calcule:
#
# 1. (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.
# 2. (operações entre *DataFrames) Calcule o total de acertos de cada aluno.
# 3. Calcule o porcentual geral de cada aluno.
# 4. Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?

# %%
import pandas as pd
import numpy as np

np.random.seed(42)
df_mat = pd.DataFrame(np.random.randint(24, size=(100, 1)), columns=['qt_acertos'])

df_por = pd.DataFrame(np.random.randint(18, size=(100, 1)), columns=['qt_acertos'])

df_geo = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['qt_acertos'])

df_ing = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['qt_acertos'])

df_his = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['qt_acertos'])

df_fis = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['qt_acertos'])

df_qui = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['qt_acertos'])

# %%
# 1) Seu código aqui
df_mat['%acerto_mat'] = (df_mat['qt_acertos'] / 24) * 100

df_por['%acerto_por'] = (df_por['qt_acertos'] / 18) * 100

df_geo['%acerto_geo'] = (df_geo['qt_acertos'] / 8) * 100

df_ing['%acerto_ing'] = (df_ing['qt_acertos'] / 8) * 100

df_his['%acerto_his'] = (df_his['qt_acertos'] / 8) * 100

df_fis['%acerto_fis'] = (df_fis['qt_acertos'] / 12) * 100

df_qui['%acerto_qui'] = (df_qui['qt_acertos'] / 12) * 100

# %%
# 2) Seu código aqui
df = pd.concat([df_mat['qt_acertos'], df_mat['%acerto_mat'], df_por['qt_acertos'], df_por['%acerto_por'], df_geo['qt_acertos'], df_geo['%acerto_geo'], df_ing['qt_acertos'], df_ing['%acerto_ing'], df_his['qt_acertos'], df_his['%acerto_his'],  df_fis['qt_acertos'], df_fis['%acerto_fis'], df_qui['qt_acertos'], df_qui['%acerto_qui']], axis=1)

df.columns = ['qt_acertos_mat', '%acerto_mat', 'qt_acertos_por', '%acerto_por', 'qt_acertos_geo', '%acerto_geo', 'qt_acertos_ing', '%acerto_ing', 'qt_acertos_his', '%acerto_his', 'qt_acertos_fis', '%acerto_fis', 'qt_acertos_qui', '%acerto_qui']

df['total_acertos'] = (df['qt_acertos_mat'] + df['qt_acertos_por'] + df['qt_acertos_geo'] + df['qt_acertos_ing'] + df['qt_acertos_his'] + df['qt_acertos_fis'] + df['qt_acertos_qui'])

df.head()
# Out:
#    qt_acertos_mat  %acerto_mat  qt_acertos_por  %acerto_por  qt_acertos_geo  \
# 0               6    25.000000               7    38.888889               7
# 1              19    79.166667              10    55.555556               0
# 2              14    58.333333              16    88.888889               0
# 3              10    41.666667               7    38.888889               3
# 4               7    29.166667               2    11.111111               2
#
#    %acerto_geo  qt_acertos_ing  %acerto_ing  qt_acertos_his  %acerto_his  \
# 0         87.5               3         37.5               1         12.5
# 1          0.0               0          0.0               0          0.0
# 2          0.0               5         62.5               7         87.5
# 3         37.5               4         50.0               0          0.0
# 4         25.0               7         87.5               0          0.0
#
# ...

# %%
# 3) Seu código aqui
df['percentual_geral'] = (df['total_acertos'] / 90) * 100
df
# Out:
#     qt_acertos_mat  %acerto_mat  qt_acertos_por  %acerto_por  qt_acertos_geo  \
# 0                6    25.000000               7    38.888889               7
# 1               19    79.166667              10    55.555556               0
# 2               14    58.333333              16    88.888889               0
# 3               10    41.666667               7    38.888889               3
# 4                7    29.166667               2    11.111111               2
# ..             ...          ...             ...          ...             ...
# 95               6    25.000000               4    22.222222               7
# 96               8    33.333333               1     5.555556               4
# 97              23    95.833333               5    27.777778               0
# 98               0     0.000000              10    55.555556               3
# 99              11    45.833333              15    83.333333               0
#
# ...

# %%
# 4) Seu código aqui
maior_que_nota_corte = df[df['total_acertos'] > 45].shape[0]
print(maior_que_nota_corte)
# Out:
# 31

# %% [markdown]
# ## 2) Vestibular II
#
# Ainda sobre o mesmo banco de dados:
#
# 1. Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo *DataFrame* com os alunos desqualificados por este critério.
# 2. Quantos são esses alunos?
# 3. Qual a média desses alunos em história e geografia?
# 4. Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

# %%
# seu código aqui

df_desqualificados = df[(df['qt_acertos_mat'] == 0) | (df['qt_acertos_fis'] == 0) | (df['qt_acertos_qui'] == 0)]

print('quantidade de alunos desqualificados:', df_desqualificados.shape[0])

media_his_geo = df_desqualificados[['qt_acertos_his', 'qt_acertos_geo']].mean()

print('media em historia e geografica dos alunos desqualificados:', media_his_geo)

df_aprovacoes_segunda_fase = df[(df['total_acertos'] > 45) & (~df.index.isin(df_desqualificados.index))]
#nao sei se essse é o melhor jeito mas foi o que eu achei que menos ficaria enrolado
# Out:
# quantidade de alunos desqualificados: 23
# media em historia e geografica dos alunos desqualificados: qt_acertos_his    3.434783
# qt_acertos_geo    3.217391
# dtype: float64

# %% [markdown]
# ## 3) Vacinações no Acre
# Vamos trabalhar agora com a base de vacinações no Acre. Para facilitar a sua vida, copiamos o link do arquivo na célula abaixo.
#
# 1. Quantas vacinas estão registradas nessa base?
# 2. Quantos pacientes foram vacinados? (considere um paciente para cada valor único de ```paciente_id```)
# 3. Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método ```.unique()```.
# 4. Quantos pacientes com menos de 18 anos foram vacinados?
# 5. Quantos estabelecimentos aplicaram vacina no Acre?
#
#
# **OBS:** O portal do DATASUS pode apresentar instabilidades, retornando um erro na segunda célula abaixo. Por este motivo está disponível uma base estática, que se for baixada para o seu *working directory* pode ser lida com este comando: ```df = pd.read_csv('registros de vacinacao covid ACRE.csv', sep=';')```.
#
# **OBS2:** Para saber qual é o seu working directory, rode no jupyter: ```!pwd```.

# %%
arquivo = 'DadosVacinacao.csv'
df = pd.read_csv(arquivo, sep=';')
df.dtypes
# Out:
# document_id                                  object
# paciente_id                                  object
# paciente_idade                                int64
# paciente_dataNascimento                      object
# paciente_enumSexoBiologico                   object
# paciente_racaCor_codigo                       int64
# paciente_racaCor_valor                       object
# paciente_endereco_coIbgeMunicipio           float64
# paciente_endereco_coPais                    float64
# paciente_endereco_nmMunicipio                object
# paciente_endereco_nmPais                     object
# paciente_endereco_uf                         object
# paciente_endereco_cep                       float64
# paciente_nacionalidade_enumNacionalidade     object
# estabelecimento_valor                         int64
# estabelecimento_razaoSocial                  object
# estalecimento_noFantasia                     object
# estabelecimento_municipio_codigo              int64
# ...

# %%
# 1) Sua solução aqui
df.shape[0]
# Out:
# 390911

# %%
# 2)
df['paciente_id'].nunique()
# Out:
# 318850

# %%
# 3)
df_primeira_dose = df[df['vacina_descricao_dose'].str.contains('1ª', na=False)]['paciente_id'].unique()
len(df_primeira_dose)
# Out:
# 144276

# %%
# 3) solução alternativa
df[df['vacina_descricao_dose'].str.contains('1ª', na=False)]['paciente_id'].nunique()
# Out:
# 144276

# %%
# 4)
df[df['paciente_idade'] < 18]['paciente_id'].nunique()
# Out:
# 69726

# %%
# 5)
df[df['estabelecimento_uf'] == 'AC' ]['paciente_id'].nunique()
# Out:
# 318850

# %% [markdown]
# ## 4) Vacinação II
# Gere um *DataFrame* que contenha somente os estabelecimentos que aplicaram vcinas a menores de 18 anos. Nesse *DataFrame* devem conter somente os dados dos estabelecimentos, mais uma coluna sendo a quantidade de vacinas que o estabelecimento aplicou a menores de 18 anos.
#
# 1. crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
# 2. crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**
# 3. Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.
# 3. a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
# 4. usando o método *.loc*, selecione somente essas variáveis
# 5. Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

# %%
# 1)
df_menores_18 = df[df['paciente_idade'] < 18].copy()

# %%
# 2)
colunas = df_menores_18.columns.tolist()

# %%
# 3)
df_menores_18['vacina_categoria_nome'].value_counts()
# Out:
# vacina_categoria_nome
# Faixa Etária                                      49015
# Povos Indígenas                                    4934
# Outros                                             3755
# Povos e Comunidades Tradicionais                    875
# Trabalhadores de Saúde                              264
# Comorbidades                                         58
# População Privada de Liberdade                       53
# Gestantes                                            47
# Trabalhadores da Educação                            14
# Trabalhadores de Transporte                          13
# Pessoas com Deficiência                              11
# Pessoas Institucionalizadas                           3
# Pessoas de 60 anos ou mais institucionalizadas        1
# Puérperas                                             1
# Name: count, dtype: int64

# %%
# 4)
colunas_estabelecimento = [col for col in colunas if 'estabelecimento' in col]
colunas_estabelecimento
# Out:
# ['estabelecimento_valor',
#  'estabelecimento_razaoSocial',
#  'estabelecimento_municipio_codigo',
#  'estabelecimento_municipio_nome',
#  'estabelecimento_uf']

# %%
# 5)
df_estabelecimentos = df_menores_18.loc[:, colunas_estabelecimento].copy()
df_estabelecimentos
# Out:
#         estabelecimento_valor                  estabelecimento_razaoSocial  \
# 4                     2001748         PREFEITURA MUNICIPAL DE PORTO WALTER
# 6                     6917291           PREFEITURA MUNICIPAL DE RIO BRANCO
# 19                    2001349            PREFEITURA MUNICIPAL DE BRASILEIA
# 22                    2000482           PREFEITURA MUNICIPAL DE RIO BRANCO
# 24                    2002876                 SECRETARIA MUNCIPAL DE SAUDE
# ...                       ...                                          ...
# 390888                3015548           PREFEITURA MUNICIPAL DE RIO BRANCO
# 390897                2002914      PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 390902                7014147                PREFEITURA MUNICIPAL DE FEIJO
# 390904                6917291           PREFEITURA MUNICIPAL DE RIO BRANCO
# 390910                2001772  PREFEITURA MUNICIPAL DE SANTA ROSA DO PURUS
#
# ...

# %%
# 6)
estabelecimentos_unicos = df_estabelecimentos.drop_duplicates().values.tolist()
estabelecimentos_unicos
# Out:
# [[2001748,
#   'PREFEITURA MUNICIPAL DE PORTO WALTER',
#   120039,
#   'PORTO WALTER',
#   'AC'],
#  [6917291, 'PREFEITURA MUNICIPAL DE RIO BRANCO', 120040, 'RIO BRANCO', 'AC'],
#  [2001349, 'PREFEITURA MUNICIPAL DE BRASILEIA', 120010, 'BRASILEIA', 'AC'],
#  [2000482, 'PREFEITURA MUNICIPAL DE RIO BRANCO', 120040, 'RIO BRANCO', 'AC'],
#  [2002876, 'SECRETARIA MUNCIPAL DE SAUDE', 120013, 'BUJARI', 'AC'],
#  [2001101, 'PREFEITURA MUNICIPAL DE PORTO ACRE', 120080, 'PORTO ACRE', 'AC'],
#  [7247435, 'PREFEITURA MUNICIPAL DE SAUDE', 120020, 'CRUZEIRO DO SUL', 'AC'],
#  [2000059, 'PREFEITURA MUNICIPAL DE FEIJO', 120030, 'FEIJO', 'AC'],
#  [2000016,
#   'PREFEITURA MUNICIPAL DE RODRIGUES ALVES',
#   120042,
#   'RODRIGUES ALVES',
#   'AC'],
#  [2001772,
#   'PREFEITURA MUNICIPAL DE SANTA ROSA DO PURUS',
#   120043,
#   'SANTA ROSA DO PURUS',
#   'AC'],
#  [924490, 'PREFEITURA MUNICIPAL DE FEIJO', 120030, 'FEIJO', 'AC'],
#  [2000598,
#   'PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL',
#   120020,
# ...
